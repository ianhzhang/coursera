# %%
import random
from pyspark.mllib.stat import Statistics
col1 = sc.parallelize(range(10))
col2 = sc.parallelize(range(100,110))
col3 = sc.parallelize(list(reversed(range(10))))
col4 = sc.parallelize(random.sample(range(100),10))

data = col1.zip(col2).zip(col3).zip(col4)
data.take(10)
col1.count()
# Out:
# ---------------------------------------------------------------------------
# Py4JJavaError                             Traceback (most recent call last)
# <ipython-input-57-05a086c88fc0> in <module>
#       7
#       8 data = col1.zip(col2).zip(col3).zip(col4)
# ----> 9 data.take(10)
#      10 col1.count()
#
# /usr/local/spark/python/pyspark/rdd.py in take(self, num)
#    1358
#    1359             p = range(partsScanned, min(partsScanned + numPartsToTry, totalParts))
# -> 1360             res = self.context.runJob(self, takeUpToNumLeft, p)
#    1361
#    1362             items += res
#
# /usr/local/spark/python/pyspark/context.py in runJob(self, rdd, partitionFunc, partitions, allowLocal)
#    1067         # SparkContext#runJob.
#    1068         mappedRDD = rdd.mapPartitions(partitionFunc)
# -> 1069         sock_info = self._jvm.PythonRDD.runJob(self._jsc.sc(), mappedRDD._jrdd, partitions)
#    1070         return list(_load_from_socket(sock_info, mappedRDD._jrdd_deserializer))
# ...

# %%
x= (((0, 100), 99), 13)
print(x[0][0][0])
print(x[0][0][1])
print(x[0][1])
print(x[1])
# Out:
# 0
# 100
# 99
# 13

# %%
data1 = data.map(lambda x: [x[0][0][0],x[0][0][1],x[0][1],x[1]] )

# %%
type(data1)
# Out:
# pyspark.rdd.PipelinedRDD

# %%
data1.take(10)
# Out:
# [[0, 100, 99, 47],
#  [1, 101, 98, 45],
#  [2, 102, 97, 10],
#  [3, 103, 96, 35],
#  [4, 104, 95, 50],
#  [5, 105, 94, 29],
#  [6, 106, 93, 3],
#  [7, 107, 92, 66],
#  [8, 108, 91, 75],
#  [9, 109, 90, 87]]

# %%
Statistics.corr(data1)
# Out:
# ---------------------------------------------------------------------------
# Py4JJavaError                             Traceback (most recent call last)
# <ipython-input-43-546215a8b0b1> in <module>
# ----> 1 Statistics.corr(data1)
#
# /usr/local/spark/python/pyspark/mllib/stat/_statistics.py in corr(x, y, method)
#     153
#     154         if not y:
# --> 155             return callMLlibFunc("corr", x.map(_convert_to_vector), method).toArray()
#     156         else:
#     157             return callMLlibFunc("corr", x.map(float), y.map(float), method)
#
# /usr/local/spark/python/pyspark/mllib/common.py in callMLlibFunc(name, *args)
#     128     sc = SparkContext.getOrCreate()
#     129     api = getattr(sc._jvm.PythonMLLibAPI(), name)
# --> 130     return callJavaFunc(sc, api, *args)
#     131
#     132
#
# /usr/local/spark/python/pyspark/mllib/common.py in callJavaFunc(sc, func, *args)
#     121     """ Call Java Function """
# ...
